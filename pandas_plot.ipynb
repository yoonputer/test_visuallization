# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonputer/test_visuallization/blob/master/pandas_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# iloc : 번호  / loc: 위치(이름)

# %%
df = pd.read_excel('남북한발전전력량.xlsx')
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
# 3       NaN    원자력   529   563   565   581  ...  1547  1503  1388  1564  1648  1620
# 4       NaN    신재생     -     -     -     -  ...     -    86   118   151   173   195
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
# 6       NaN     수력   156   150   142   133  ...   132   135   139   130   100   128
# 7       NaN     화력   121   113   105    88  ...    79    80    82    86    90   111
# 8       NaN    원자력     -     -     -     -  ...     -     -     -     -     -     -
#
# [9 rows x 29 columns]

# %%
df.head(3)
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
#
# [3 rows x 29 columns]

# %%
#df.iloc[0:2,0:2]
df_ns = df.iloc[[0,5],2:]

# %%
#df.loc[0:2,'전력량 (억㎾h)':'발전 전력별']
df.loc[[0,5],'1990':]
# Out:
#    1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# 0  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# 5   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
df_ns
# Out:
#    1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# 0  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# 5   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
df_ns.index = ['South','North']
df_ns
# Out:
#        1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# South  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# North   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
df_ns = df_ns.transpose()
df_ns
# Out:
#      South North
# 1990  1077   277
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
df_ns.plot()
